# %%
# python 多线程实现卖票系统
import time, random, threading

tickets = 100

class myThread(threading.Thread):
    
    def __init__(self, threadid, name):
        threading.Thread.__init__(self)
        self.threadid = threadid
        self.name = name

    def run(self):
        global tickets
        while tickets:
            threadLock = threading.Lock()
            threadLock.acquire()
            if tickets > 0:
                tickets -= 1
                print(f'{self.name}卖出一张,剩余{tickets}张票')
            threadLock.release()
            time.sleep(random.randint(0, 2))



thread1 = myThread(1, 'A')
thread2 = myThread(2, 'B')

thread1.start()
thread2.start()

thread1.join()
thread2.join()

print('exiting main thread')
# Out:
# A卖出一张,剩余99张票
# B卖出一张,剩余98张票
# A卖出一张,剩余97张票B卖出一张,剩余96张票
#
# A卖出一张,剩余95张票
# A卖出一张,剩余94张票
# B卖出一张,剩余93张票
# A卖出一张,剩余92张票
# A卖出一张,剩余91张票
# B卖出一张,剩余90张票
# A卖出一张,剩余89张票
# B卖出一张,剩余88张票
# B卖出一张,剩余87张票
# B卖出一张,剩余86张票
# B卖出一张,剩余85张票
# A卖出一张,剩余84张票
# A卖出一张,剩余83张票
# A卖出一张,剩余82张票
# B卖出一张,剩余81张票
# A卖出一张,剩余80张票
# A卖出一张,剩余79张票
# A卖出一张,剩余78张票
# A卖出一张,剩余77张票
# A卖出一张,剩余76张票
# B卖出一张,剩余75张票
# B卖出一张,剩余74张票
# A卖出一张,剩余73张票
# B卖出一张,剩余72张票
# A卖出一张,剩余71张票
# A卖出一张,剩余70张票
# B卖出一张,剩余69张票
# A卖出一张,剩余68张票
# A卖出一张,剩余67张票
# A卖出一张,剩余66张票
# A卖出一张,剩余65张票
# A卖出一张,剩余64张票
# A卖出一张,剩余63张票
# A卖出一张,剩余62张票
# B卖出一张,剩余61张票
# A卖出一张,剩余60张票
# B卖出一张,剩余59张票
# B卖出一张,剩余58张票
# A卖出一张,剩余57张票
# A卖出一张,剩余56张票
# B卖出一张,剩余55张票
# A卖出一张,剩余54张票
# B卖出一张,剩余53张票
# B卖出一张,剩余52张票
# A卖出一张,剩余51张票
# B卖出一张,剩余50张票
# A卖出一张,剩余49张票
# A卖出一张,剩余48张票
# A卖出一张,剩余47张票
# B卖出一张,剩余46张票
# B卖出一张,剩余45张票
# B卖出一张,剩余44张票
# B卖出一张,剩余43张票
# A卖出一张,剩余42张票B卖出一张,剩余41张票
#
# A卖出一张,剩余40张票
# A卖出一张,剩余39张票B卖出一张,剩余38张票
#
# B卖出一张,剩余37张票
# A卖出一张,剩余36张票B卖出一张,剩余35张票
# B卖出一张,剩余34张票
#
# B卖出一张,剩余33张票
# B卖出一张,剩余32张票
# B卖出一张,剩余31张票
# A卖出一张,剩余30张票
# A卖出一张,剩余29张票
# A卖出一张,剩余28张票B卖出一张,剩余27张票
#
# A卖出一张,剩余26张票B卖出一张,剩余25张票
#
# B卖出一张,剩余24张票
# A卖出一张,剩余23张票
# A卖出一张,剩余22张票
# B卖出一张,剩余21张票
# A卖出一张,剩余20张票
# A卖出一张,剩余19张票
# B卖出一张,剩余18张票
# B卖出一张,剩余17张票
# A卖出一张,剩余16张票
# B卖出一张,剩余15张票
# B卖出一张,剩余14张票
# A卖出一张,剩余13张票
# B卖出一张,剩余12张票
# A卖出一张,剩余11张票
# A卖出一张,剩余10张票
# B卖出一张,剩余9张票
# A卖出一张,剩余8张票
# A卖出一张,剩余7张票
# B卖出一张,剩余6张票
# A卖出一张,剩余5张票
# B卖出一张,剩余4张票
# A卖出一张,剩余3张票
# A卖出一张,剩余2张票
# A卖出一张,剩余1张票
# B卖出一张,剩余0张票
# exiting main thread
